# %% [markdown]
# ![Screenshot from 2023-07-30 11-43-55.png](<attachment:Screenshot from 2023-07-30 11-43-55.png>)

# %%
import torchmetrics as t

accuracy = t.Accuracy().to(device)

accuracy(preds, target)

# %% [markdown]
# CONFUSION MATRIX

# %%
confmat = t.ConfusionMatrix(task="binary", num_classes=2)
>>> confmat(preds, target)  # u can change task to "multiclass"

fig_, ax_ = metric.plot()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(all_targets, all_preds)

# Create a function to plot the confusion matrix
def plot_confusion_matrix(conf_matrix, class_names, figsize=(8, 6), fontsize=12):
    df_cm = pd.DataFrame(conf_matrix, index=class_names, columns=class_names)
    plt.figure(figsize=figsize)
    heatmap = sns.heatmap(df_cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title('Confusion Matrix')
    plt.show()

# Define your class names (if you have them)
class_names = ['class1', 'class2', 'class3', ...]

# Plot the confusion matrix
plot_confusion_matrix(conf_matrix, class_names)
